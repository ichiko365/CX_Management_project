# %%
import pandas as pd
# max option to show columns is 100
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('training_comparison_results.csv')
df.head()
# Out:
#     id        ASIN                                              Title  \
# 0   14  B001T0HHAG  BaBylissPRO Nano Titanium Mini Straightening Iron
# 1  185  B00FYSZDQ4                            COLOR WOW Root Cover Up
# 2   85  B00EXW53GC                     Grande Cosmetics GrandeLASH-MD
# 3  151  B000NL0T1G  MERKUR Classic 3-Piece Razor Double Edge Safte...
# 4   49  B007P0MO2U  SEXYHAIR Big Powder Play Volumizing &amp; Text...
#
#                                          Description  \
# 0  BaBylissPRO 1/2" Travel Iron with Nano Titaniu...
# 1  Color Wow root cover up, winner of 44 major be...
# 2  Created with a proprietary blend of vitamins, ...
# 3  Merkur Futur 23C Long Handle Safety Razor is t...
# 4  Can re-activate with a quick scrunching motion...
#
#                                             ImageURL  Rating  Verified  \
# 0  https://images-na.ssl-images-amazon.com/images...     5.0      True
# 1  https://images-na.ssl-images-amazon.com/images...     5.0      True
# ...
