# %%
import pandas as pd

# %%
df = pd.read_csv("../cx_dashboard/data/training_comparison_results.csv")
df[["Sentiment","gemini_sentiment", "llama_sentiment"]]
# Out:
#      Sentiment gemini_sentiment llama_sentiment
# 0          1.0         Positive        Positive
# 1          1.0         Positive        Positive
# 2          1.0         Positive        Positive
# 3          1.0         Positive        Positive
# 4          1.0         Positive        Positive
# ..         ...              ...             ...
# 155        1.0         Positive        Positive
# 156        1.0         Positive        Positive
# 157        1.0         Positive        Positive
# 158        1.0         Positive        Positive
# 159        1.0         Positive        Positive
#
# [160 rows x 3 columns]

# %%
df
# Out:
#       id        ASIN                                              Title  \
# 0     14  B001T0HHAG  BaBylissPRO Nano Titanium Mini Straightening Iron
# 1    185  B00FYSZDQ4                            COLOR WOW Root Cover Up
# 2     85  B00EXW53GC                     Grande Cosmetics GrandeLASH-MD
# 3    151  B000NL0T1G  MERKUR Classic 3-Piece Razor Double Edge Safte...
# 4     49  B007P0MO2U  SEXYHAIR Big Powder Play Volumizing &amp; Text...
# ..   ...         ...                                                ...
# 155  183  B001T0HHDS                    BaBylissPRO Nano Titanium Dryer
# 156   57  B00FYSZDQ4                            COLOR WOW Root Cover Up
# 157  189  B000NL0T1G  MERKUR Classic 3-Piece Razor Double Edge Safte...
# 158  136  B002K6AHQY   CND Vinylux Weekly Nail Polish, Rock Royalty,...
# 159   84  B002A9JONI                                      blinc Mascara
#
#                                            Description  \
# ...

# %%
df[["Review","Sentiment","gemini_key_drivers", "llama_key_drivers"]]
# Out:
#                                                 Review  Sentiment  \
# 0                                        VERY USEFUL!!        1.0
# 1    this stuff is fantastic. Fills in area of thin...        1.0
# 2    It works. My eyes are sensitive and get a bit ...        1.0
# 3    It took some getting used to, but I now love u...        1.0
# 4    Amazing product. A tiny amount does wonders fo...        1.0
# ..                                                 ...        ...
# 155  Best hair dryer I have ever owned. It usually ...        1.0
# 156  This stuff saves me.! Lets me go extra time be...        1.0
# 157  Happy with this razor. Wish I would have purch...        1.0
# 158  perfect color for my nails. Wears as promised....        1.0
# 159                 Great for sensitive skin and eyes.        1.0
#
#                                     gemini_key_drivers  \
# 0                  {'Product Performance': 'Positive'}
# 1    {'Product Performance': 'Positive', 'Longevity...
# ...

# %%
df["Review"].head().tolist()
# Out:
# ['VERY USEFUL!!',
#  'this stuff is fantastic. Fills in area of thinning grey hair just as described and stays until washed out. great product',
#  'It works. My eyes are sensitive and get a bit irritated but it works well.',
#  "It took some getting used to, but I now love using this over disposable ones.\nPros:  Long term, much cheaper than disposables.\n  Gives a close shave.\nCon:  Needed to get used to it, but that is not the product's fault.  That is due to inexperience using the safety razor.",
#  'Amazing product. A tiny amount does wonders for shaping my hair. I love the small size for travel.']

# %%
df["gemini_key_drivers"].head().tolist()
# Out:
# ["{'Product Performance': 'Positive'}",
#  "{'Product Performance': 'Positive', 'Longevity': 'Positive'}",
#  "{'Product Performance': 'Positive', 'Skin Compatibility': 'Negative'}",
#  "{'Value for Money': 'Positive', 'Product Performance': 'Positive'}",
#  "{'Product Performance': 'Positive', 'Value for Money': 'Positive', 'Packaging': 'Positive'}"]

# %%
df["llama_key_drivers"].head().tolist()
# Out:
# ["{'Value for Money': 'Positive'}",
#  "{'Product Performance': 'Positive'}",
#  "{'Product Performance': 'Positive'}",
#  "{'Value for Money': 'Positive', 'Product Performance': 'Positive'}",
#  "{'Product Performance': 'Positive', 'Packaging': 'Positive'}"]
